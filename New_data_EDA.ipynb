# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('preprocessed_train_essays.csv')

# %% [markdown]
# # Basic EDA

# %%
# Display the first few rows of the dataframe
print(df.head())

# Get a concise summary of the dataframe
print(df.info())

# Get statistical summary of numerical columns
print(df.describe())

# Check for missing values
print(df.isnull().sum())
# Out:
#    Unnamed: 0.1  Unnamed: 0          id  prompt_id  \
# 0             0           0  e_ddxvqx5i          0
# 1             1           1  e_hi0yzrcv          0
# 2             2           2  e_uesv4xha          0
# 3             3           3  e_2tl5ylwy          0
# 4             4           4  e_s6ci4vj0          0
#
#                                                 text  generated  essay_length
# 0  recent years growing movement limit car usage ...          1          1143
# 1  cars life ever met humanoid like desire usage ...          1          2311
# 2  car considered many nessecity everyday life ho...          1          1489
# 3  h ello fellow citezens inform limit car usage ...          0          1030
# 4  ever known feels able breath probably someday ...          1           896
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165767 entries, 0 to 165766
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0.1  165767 non-null  int64
#  1   Unnamed: 0    165767 non-null  int64
#  2   id            165767 non-null  object
#  3   prompt_id     165767 non-null  int64
#  4   text          165767 non-null  object
#  5   generated     165767 non-null  int64
#  6   essay_length  165767 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 8.9+ MB
# None
#         Unnamed: 0.1     Unnamed: 0      prompt_id      generated  \
# count  165767.000000  165767.000000  165767.000000  165767.000000
# mean    82883.000000   82883.000000      12.869944       0.781350
# std     47852.955374   47852.955374      25.215367       0.413332
# min         0.000000       0.000000       0.000000       0.000000
# 25%     41441.500000   41441.500000       3.000000       1.000000
# 50%     82883.000000   82883.000000       6.000000       1.000000
# 75%    124324.500000  124324.500000      10.000000       1.000000
# max    165766.000000  165766.000000     103.000000       1.000000
#
#         essay_length
# count  165767.000000
# mean     1440.975906
# std       809.508474
# min         3.000000
# 25%       851.000000
# 50%      1277.000000
# 75%      1846.000000
# max     27971.000000
# Unnamed: 0.1    0
# Unnamed: 0      0
# id              0
# prompt_id       0
# text            0
# generated       0
# essay_length    0
# dtype: int64

# %% [markdown]
# # Distribution of Target Variable

# %%
# Plot the distribution of the target variable
sns.countplot(x='generated', data=df)
plt.title('Distribution of Generated Essays')
plt.show()

# %% [markdown]
# # Essay Length Distribution

# %%
# Check for missing values in the 'text' column
print(df['text'].isnull().sum())
df['text'] = df['text'].astype(str)
df['essay_length'] = df['text'].apply(len)

# Recheck the first few entries
print(df.head())
# Out:
# 1
#    Unnamed: 0.1  Unnamed: 0          id  prompt_id  \
# 0             0           0  e_ddxvqx5i          0
# 1             1           1  e_hi0yzrcv          0
# 2             2           2  e_uesv4xha          0
# 3             3           3  e_2tl5ylwy          0
# 4             4           4  e_s6ci4vj0          0
#
#                                                 text  generated  essay_length
# 0  recent years growing movement limit car usage ...          1          1143
# 1  cars life ever met humanoid like desire usage ...          1          2311
# 2  car considered many nessecity everyday life ho...          1          1489
# 3  h ello fellow citezens inform limit car usage ...          0          1030
# 4  ever known feels able breath probably someday ...          1           896

# %%
# Plot the distribution of essay lengths
plt.figure(figsize=(10, 6))
sns.histplot(df['essay_length'], bins=50, kde=True)
plt.title('Distribution of Essay Lengths')
plt.xlabel('Essay Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Plotting most common words

# %%
from collections import Counter

word_counts = Counter(" ".join(df["text"]).split())

most_common_words = word_counts.most_common(20)
words_df = pd.DataFrame(most_common_words, columns=['word', 'frequency'])

plt.figure(figsize=(12, 8))
sns.barplot(x='frequency', y='word', data=words_df)
plt.title('Most Common Words')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()
